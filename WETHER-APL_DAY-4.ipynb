# %%
import requests
api_key='d0954d032ffd4aaba2653648242802'
city='Guntur'
url=f"http://api.weatherapi.com/v1/current.json?key={api_key}&q={city}"
responce=requests.get(url)
data=responce.json()
print(data)
# Out:
# {'location': {'name': 'Guntur', 'region': 'Andhra Pradesh', 'country': 'India', 'lat': 16.3, 'lon': 80.45, 'tz_id': 'Asia/Kolkata', 'localtime_epoch': 1709133688, 'localtime': '2024-02-28 20:51'}, 'current': {'last_updated_epoch': 1709133300, 'last_updated': '2024-02-28 20:45', 'temp_c': 24.1, 'temp_f': 75.4, 'is_day': 0, 'condition': {'text': 'Clear ', 'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png', 'code': 1000}, 'wind_mph': 6.0, 'wind_kph': 9.7, 'wind_degree': 173, 'wind_dir': 'S', 'pressure_mb': 1012.0, 'pressure_in': 29.88, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 77, 'cloud': 4, 'feelslike_c': 26.0, 'feelslike_f': 78.7, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 1.0, 'gust_mph': 11.2, 'gust_kph': 18.0}}

# %%
type(data)
# Out:
# dict

# %%
data['location']['name']
# Out:
# 'Guntur'

# %%
print("city:",data['location']['name'])
# Out:
# city: Guntur

# %%
print("city",data['location']['name'])
print("state",data['location']['region'])
print("country",data['location']['country'])
print("temperature",data['current']['temp_c'])
print("wind",data['current']['wind_mph'])
print("humidity",data['current']['humidity'])
print("pressure",data['current']['pressure_mb'])
print("miles",data['current']['vis_miles'])
print("feels",data['current']['feelslike_c'])
# Out:
# city Guntur
# state Andhra Pradesh
# country India
# temperature 24.1
# wind 6.0
# humidity 77
# pressure 1012.0
# miles 6.0
# feels 26.0

# %%
import requests
api_key='d0954d032ffd4aaba2653648242802'
city=input("enter city name:")
url=f"http://api.weatherapi.com/v1/current.json?key={api_key}&q={city}"
responce=requests.get(url)
data=responce.json()
print(data)
print("city",data['location']['name'])
print("state",data['location']['region'])
print("country",data['location']['country'])
print("temperature",data['current']['temp_c'])
print("wind",data['current']['wind_mph'])
print("humidity",data['current']['humidity'])
print("pressure",data['current']['pressure_mb'])
print("miles",data['current']['vis_miles'])
print("feels",data['current']['feelslike_c'])
# Out:
# enter city name:guntur
# {'location': {'name': 'Guntur', 'region': 'Andhra Pradesh', 'country': 'India', 'lat': 16.3, 'lon': 80.45, 'tz_id': 'Asia/Kolkata', 'localtime_epoch': 1709133864, 'localtime': '2024-02-28 20:54'}, 'current': {'last_updated_epoch': 1709133300, 'last_updated': '2024-02-28 20:45', 'temp_c': 24.1, 'temp_f': 75.4, 'is_day': 0, 'condition': {'text': 'Clear ', 'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png', 'code': 1000}, 'wind_mph': 6.0, 'wind_kph': 9.7, 'wind_degree': 173, 'wind_dir': 'S', 'pressure_mb': 1012.0, 'pressure_in': 29.88, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 77, 'cloud': 4, 'feelslike_c': 26.0, 'feelslike_f': 78.7, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 1.0, 'gust_mph': 11.2, 'gust_kph': 18.0}}
# city Guntur
# state Andhra Pradesh
# country India
# temperature 24.1
# wind 6.0
# humidity 77
# pressure 1012.0
# miles 6.0
# feels 26.0
