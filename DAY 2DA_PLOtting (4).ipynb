# %%
#ploting list
from matplotlib import pyplot as plt
x=[1,2,3,4]
y=[34,56,78,98]
plt.plot(x,y)#line grapy
plt.title("my first plot")
plt.xlabel('x values')
plt.ylabel('y values')
#tittle,labels,legend,color,width,marker
# Out:
# Text(0, 0.5, 'y values')

# %%
#there are 5 subjects Psychoiogy,nanology,medicien,orchology,anthrology two students have applyed to do masters in any of this 5 studies with a line plot shown in which field they can excel the cutoff is 70
#stu1=[67,45,73,71,57]
#std2[43,67,68,53,85]
#ploting list
from matplotlib import pyplot as plt
sub=["psy","nano","med","onc","anthro"]
std1=[67,45,73,71,57]
std2=[43,67,68,53,85]
cut=[70,70,70,70,70]
#student
#plt.plottye(x,y label,color,marks,linewidth,linestyle)
plt.plot(sub,std1,label="std1",marker='P')
#student2
plt.plot(sub,std2,label="std2",marker='H')
#cutoff
plt.plot(sub,cut,label="cutoff",color='k',linestyle=':',linewidth=3)
plt.xlabel("subject")
plt.ylabel("marks")
plt.legend()

# %%
#An India Vs Australia match is on live India has given 268 as a target for Australia the runs for every 5 overs are given as follows
i=[25,51,84,131,1690,189,220,250,267,297]
#Austrlia has completed 25 overs
a=[50,41,94,110,151]
#plot over spaces runs for both the countries with India has a blue line&Australia has a Yellow line giving appropriate labels&legends, the marker for India is flag &Australia is plus
#take over from A range functions create runs as arrays  linebit=2
from matplotlib import pyplot as plt
import numpy as np
o=np.arange(5,51,5)
r=np.arange(5,26,5)
Ind=np.array([25,51,84,131,160,189,220,250,267,297])
Aus=np.array([15,41,94,110,151])
plt.title("India vs Australia")
plt.plot( o,Ind,label='India',color='b',marker='>')
plt.plot( r,Aus,label='Australia', color='y',marker='<')#line grapy
plt.xlabel('overs')
plt.ylabel('runs')
plt.legend()
plt. grid()
