# %%
import requests

url = "https://covid-19-tracking.p.rapidapi.com/v1/usa"

headers = {
	"X-RapidAPI-Key": "922ac22f29mshfdfdc1d149c727dp13d584jsn9a814473023b",
	"X-RapidAPI-Host": "covid-19-tracking.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'Active Cases_text': '', 'Country_text': 'USA', 'Last Update': '2024-02-29 03:42', 'New Cases_text': '', 'New Deaths_text': '', 'Total Cases_text': '111,521,313', 'Total Deaths_text': '1,211,319', 'Total Recovered_text': '109,242,098'}
